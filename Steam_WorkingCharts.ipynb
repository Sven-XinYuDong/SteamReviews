# %%
import requests
import json
import pandas as pd
import altair as alt
# Out:
# /Users/matthewyau/opt/anaconda3/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (5.1.0)/charset_normalizer (2.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %% [markdown]
# # Plan

# %%
#GRAPHS WE MIGHT WANT TO IMPLEMENT:

#Gaming preferences of friend group
    #Get common games (value counts of games that most people own)
    #Favorite games (show top 3 most played game)
    #Compare genres between two friends


#Leaderboards
    #Total number of hours played
    #Biggest spender
    #Biggest collector (greatest number of games owned)
    #Biggest collector of unplayed games (greatest number of games owned that do not have any hours played in it)

#Profile analysis
    #Genres played
    #Total number of games owned, etc...

# %% [markdown]
# # Code
#
# #Always enter the SteamID I pasted below to search for people

# %%
#SteamId = 76561197996661065

# %% [markdown]
# #### Get a person's friend list off steam ID

# %%
#Implementation:
#Get friend list based off of Steam ID

def get_friend_id(steamId):
    friendIds = []
    try:
        friendlist = requests.get("http://api.steampowered.com/ISteamUser/GetFriendList/v0001/?key=3D41F12368AF3E305A8233ABFB965CA2&relationship=friend&steamid=" + str(steamId)).json()

        friendIds.append(str(steamId))
        for friend in friendlist["friendslist"]["friends"]:
            friendIds.append(friend["steamid"])
    except:
        print("Error occurred in extracting friend list")

    return friendIds

# %% [markdown]
# #### Get all of your own and friends names and profile pictures

# %%
def get_friend_name(friendIds):
    friendSearchQuery = ""
    for i in friendIds:
        friendSearchQuery += i + ","
    try:
        friendName = requests.get("http://api.steampowered.com/ISteamUser/GetPlayerSummaries/v0002/?key=3D41F12368AF3E305A8233ABFB965CA2&steamids=" + friendSearchQuery[:-1]).json()
        friendNameList = {}
        for friendName in friendName["response"]["players"]:
            friendNameList[friendName["personaname"]] = []
            friendNameList[friendName["personaname"]].append(friendName["steamid"])
            friendNameList[friendName["personaname"]].append(friendName["avatar"])
    except:
        print("Error occurred in extracting friend names")
    return friendNameList
    

#get_friend_name(get_friend_id(76561197996661065))

# %% [markdown]
# #### Get all of your own and friends game libraries

# %%
def get_game_library(friendNameList):
    for friend in friendNameList:
        try:
            gameLibrary = requests.get("https://api.steampowered.com/IPlayerService/GetOwnedGames/v0001/?key=3D41F12368AF3E305A8233ABFB965CA2&include_appinfo=1&format=json&steamid="
                                       + friendNameList[friend][0]).json()["response"]["games"]
            friendNameList[friend].append(gameLibrary)
        except:
            print("Could not load game library for", friend)
    for friend in list(friendNameList):
        if len(friendNameList[friend]) == 2:
            del(friendNameList[friend])
    return friendNameList

# %%
#get_game_library(get_friend_name(get_friend_id(76561197996661065)))

# %% [markdown]
# #### Get most of game prices for games (if it exists)

# %%
#Implementation:
#Get game prices

def get_game_prices(friendNameList):
    appIdList = []
    for friend in friendNameList:
        for game in friendNameList[friend][2]:
            appIdList.append(game["appid"])
    appString = ""
    for app in appIdList:
        appString = appString + str(app) + ","
    prices = requests.get("https://store.steampowered.com/api/appdetails?appids=" + appString + "&filters=price_overview").json()    
    for friend in friendNameList:
        for game in friendNameList[friend][2]:
            try:
                if prices[str(game["appid"])]["success"]:
                    if prices[str(game["appid"])]["data"] != []:
                        game["price"] = float(prices[str(game["appid"])]["data"]["price_overview"]["final_formatted"][5:])
            except:
                pass
    return friendNameList

# %%
friendNameList = get_game_prices(get_game_library(get_friend_name(get_friend_id(76561197996661065))))

# %% [markdown]
# ### Constuct DataFrame

# %%
#Implementation:
#Convert friendList to pandas dataframe
def friendlist_to_dataframe(friendNameList):
    fullLst = []
    
    for friend in friendNameList:
        lst = []
        lst.append(friend) #Append friend name to list
        lst.append(friendNameList[friend][1]) #Append friend avatar to list

        gameLst = [] #Start appending library of games to list
        for game in friendNameList[friend][2]: 
            gameLst.append(game["name"])   
        lst.append(gameLst) #End appending library of games to list
    
        totalNumGamesOwned = len(gameLst) #Append total number of games owned
        lst.append(totalNumGamesOwned)
    
        
        zeroPlaytimeGames = 0 #Append total number of games owned with zero playtime
        for game in friendNameList[friend][2]:
            if game["playtime_forever"] == 0:
                zeroPlaytimeGames += 1
        lst.append(zeroPlaytimeGames)
        
    
        priceLst = []
        for game in friendNameList[friend][2]:
            try:
                priceLst.append(game["price"])
            except:
                pass
        #lst.append(priceLst) #Append purchase price (full price, not on sale) for all games owned
        
        try:
            lst.append(sum(priceLst)) #Uncomment this line if we want the sum of prices for all games owned instead of individual items
        except:
            pass
    
        playtimeLst = []
        for game in friendNameList[friend][2]:
            playtimeLst.append(game["playtime_forever"])
        #lst.append(playtimeLst) #Appending total playtime for all games owned
        lst.append(sum(playtimeLst))
    

    

                                 
    
        fullLst.append(lst)
    return pd.DataFrame(fullLst, columns = ["Name", "ProfilePicture", "GameList", "TotalNumGames", "ZeroPlaytimeGames", "GamePrice", "Playtime"])

# %%
steamData = friendlist_to_dataframe(friendNameList)

# %%
def chart_plotter(dataframe):
    
    dataframe = dataframe.melt(["Name", "ProfilePicture", "GameList"])

    
    
    dataframe["Text"] = (["Total number of games owned"] * dataframe["variable"].value_counts()[0] 
                         + ["Total amount of games owned with zero playtime"] * dataframe["variable"].value_counts()[0] 
                         + ["Total amount of dollars spent on games ($CAD)"] * dataframe["variable"].value_counts()[0] 
                         + ["Total number of minutes spent playing games"] * dataframe["variable"].value_counts()[0] 
                     )
    return dataframe

# %%
plotData = chart_plotter(steamData)
plotData
# Out:
#                     Name                                     ProfilePicture  \
# 0                  卷毛毛秀丽  https://avatars.akamai.steamstatic.com/2f66582...
# 1               Tedd2008  https://avatars.akamai.steamstatic.com/f3065ac...
# 2                   audz  https://avatars.akamai.steamstatic.com/fef49e7...
# 3                   马铃鼠鼠  https://avatars.akamai.steamstatic.com/302685d...
# 4   All About That Money  https://avatars.akamai.steamstatic.com/9f5ee8f...
# 5                Stealth  https://avatars.akamai.steamstatic.com/6a054c8...
# 6                 HenryL  https://avatars.akamai.steamstatic.com/08666eb...
# 7                   matt  https://avatars.akamai.steamstatic.com/4e8b518...
# 8            Waul Palker  https://avatars.akamai.steamstatic.com/b0d0557...
# 9                  卷毛毛秀丽  https://avatars.akamai.steamstatic.com/2f66582...
# 10              Tedd2008  https://avatars.akamai.steamstatic.com/f3065ac...
# 11                  audz  https://avatars.akamai.steamstatic.com/fef49e7...
# 12                  马铃鼠鼠  https://avatars.akamai.steamstatic.com/302685d...
# 13  All About That Money  https://avatars.akamai.steamstatic.com/9f5ee8f...
# 14               Stealth  https://avatars.akamai.steamstatic.com/6a054c8...
# 15                HenryL  https://avatars.akamai.steamstatic.com/08666eb...
# 16                  matt  https://avatars.akamai.steamstatic.com/4e8b518...
# 17           Waul Palker  https://avatars.akamai.steamstatic.com/b0d0557...
# 18                 卷毛毛秀丽  https://avatars.akamai.steamstatic.com/2f66582...
# 19              Tedd2008  https://avatars.akamai.steamstatic.com/f3065ac...
# 20                  audz  https://avatars.akamai.steamstatic.com/fef49e7...
# 21                  马铃鼠鼠  https://avatars.akamai.steamstatic.com/302685d...
# 22  All About That Money  https://avatars.akamai.steamstatic.com/9f5ee8f...
# 23               Stealth  https://avatars.akamai.steamstatic.com/6a054c8...
# 24                HenryL  https://avatars.akamai.steamstatic.com/08666eb...
# 25                  matt  https://avatars.akamai.steamstatic.com/4e8b518...
# 26           Waul Palker  https://avatars.akamai.steamstatic.com/b0d0557...
# 27                 卷毛毛秀丽  https://avatars.akamai.steamstatic.com/2f66582...
# 28              Tedd2008  https://avatars.akamai.steamstatic.com/f3065ac...
# 29                  audz  https://avatars.akamai.steamstatic.com/fef49e7...
# 30                  马铃鼠鼠  https://avatars.akamai.steamstatic.com/302685d...
# 31  All About That Money  https://avatars.akamai.steamstatic.com/9f5ee8f...
# 32               Stealth  https://avatars.akamai.steamstatic.com/6a054c8...
# 33                HenryL  https://avatars.akamai.steamstatic.com/08666eb...
# 34                  matt  https://avatars.akamai.steamstatic.com/4e8b518...
# 35           Waul Palker  https://avatars.akamai.steamstatic.com/b0d0557...
#
#                                              GameList           variable  \
# 0   [The Forest, Papers, Please, Cuphead, Dark Dec...      TotalNumGames
# 1   [Terraria, Grand Theft Auto V, Mini Metro, AST...      TotalNumGames
# 2   [Portal 2, Terraria, Starbound, Starbound - Un...      TotalNumGames
# 3   [Counter-Strike, Counter-Strike: Condition Zer...      TotalNumGames
# 4   [Counter-Strike: Source, Midnight Club II, Bur...      TotalNumGames
# 5   [Garry's Mod, Mass Effect (2007), Star Wars: B...      TotalNumGames
# 6   [Total War: EMPIRE - Definitive Edition, Heart...      TotalNumGames
# 7   [Counter-Strike: Source, Total War: MEDIEVAL I...      TotalNumGames
# 8   [Battlefield: Bad Company™ 2, Super Monday Nig...      TotalNumGames
# 9   [The Forest, Papers, Please, Cuphead, Dark Dec...  ZeroPlaytimeGames
# 10  [Terraria, Grand Theft Auto V, Mini Metro, AST...  ZeroPlaytimeGames
# 11  [Portal 2, Terraria, Starbound, Starbound - Un...  ZeroPlaytimeGames
# 12  [Counter-Strike, Counter-Strike: Condition Zer...  ZeroPlaytimeGames
# 13  [Counter-Strike: Source, Midnight Club II, Bur...  ZeroPlaytimeGames
# 14  [Garry's Mod, Mass Effect (2007), Star Wars: B...  ZeroPlaytimeGames
# 15  [Total War: EMPIRE - Definitive Edition, Heart...  ZeroPlaytimeGames
# 16  [Counter-Strike: Source, Total War: MEDIEVAL I...  ZeroPlaytimeGames
# 17  [Battlefield: Bad Company™ 2, Super Monday Nig...  ZeroPlaytimeGames
# 18  [The Forest, Papers, Please, Cuphead, Dark Dec...          GamePrice
# 19  [Terraria, Grand Theft Auto V, Mini Metro, AST...          GamePrice
# 20  [Portal 2, Terraria, Starbound, Starbound - Un...          GamePrice
# 21  [Counter-Strike, Counter-Strike: Condition Zer...          GamePrice
# 22  [Counter-Strike: Source, Midnight Club II, Bur...          GamePrice
# 23  [Garry's Mod, Mass Effect (2007), Star Wars: B...          GamePrice
# 24  [Total War: EMPIRE - Definitive Edition, Heart...          GamePrice
# 25  [Counter-Strike: Source, Total War: MEDIEVAL I...          GamePrice
# 26  [Battlefield: Bad Company™ 2, Super Monday Nig...          GamePrice
# 27  [The Forest, Papers, Please, Cuphead, Dark Dec...           Playtime
# 28  [Terraria, Grand Theft Auto V, Mini Metro, AST...           Playtime
# 29  [Portal 2, Terraria, Starbound, Starbound - Un...           Playtime
# 30  [Counter-Strike, Counter-Strike: Condition Zer...           Playtime
# 31  [Counter-Strike: Source, Midnight Club II, Bur...           Playtime
# 32  [Garry's Mod, Mass Effect (2007), Star Wars: B...           Playtime
# 33  [Total War: EMPIRE - Definitive Edition, Heart...           Playtime
# 34  [Counter-Strike: Source, Total War: MEDIEVAL I...           Playtime
# 35  [Battlefield: Bad Company™ 2, Super Monday Nig...           Playtime
#
#         value                                            Text
# 0       30.00                     Total number of games owned
# 1       23.00                     Total number of games owned
# 2       19.00                     Total number of games owned
# 3       63.00                     Total number of games owned
# 4       49.00                     Total number of games owned
# 5       76.00                     Total number of games owned
# 6      133.00                     Total number of games owned
# 7       58.00                     Total number of games owned
# 8       40.00                     Total number of games owned
# 9       13.00  Total amount of games owned with zero playtime
# 10       0.00  Total amount of games owned with zero playtime
# 11       5.00  Total amount of games owned with zero playtime
# 12      63.00  Total amount of games owned with zero playtime
# 13      28.00  Total amount of games owned with zero playtime
# 14      36.00  Total amount of games owned with zero playtime
# 15      15.00  Total amount of games owned with zero playtime
# 16      20.00  Total amount of games owned with zero playtime
# 17      14.00  Total amount of games owned with zero playtime
# 18     620.20   Total amount of dollars spent on games ($CAD)
# 19     770.35   Total amount of dollars spent on games ($CAD)
# 20     377.16   Total amount of dollars spent on games ($CAD)
# 21    1039.26   Total amount of dollars spent on games ($CAD)
# 22     540.22   Total amount of dollars spent on games ($CAD)
# 23     950.39   Total amount of dollars spent on games ($CAD)
# 24    4113.81   Total amount of dollars spent on games ($CAD)
# 25    1697.44   Total amount of dollars spent on games ($CAD)
# 26     341.61   Total amount of dollars spent on games ($CAD)
# 27    3352.00     Total number of minutes spent playing games
# 28   86762.00     Total number of minutes spent playing games
# 29   27561.00     Total number of minutes spent playing games
# 30       0.00     Total number of minutes spent playing games
# 31   28501.00     Total number of minutes spent playing games
# 32   45381.00     Total number of minutes spent playing games
# 33  240092.00     Total number of minutes spent playing games
# 34   74715.00     Total number of minutes spent playing games
# 35  124272.00     Total number of minutes spent playing games

# %% [markdown]
# ### Dataframe Operations

# %%
def compare_chart(dataframe):
    selection_options = alt.binding_select(options = dataframe["variable"].unique().tolist())
    selection = alt.selection_single(name = "Genre", fields = ["variable"], bind = selection_options, init = {"variable": "Playtime"})
    brush = alt.selection_interval(empty = "none")
    
    base = alt.Chart(dataframe).mark_bar().encode(
        x = alt.Y("value", title = [" ", " "]),
        y = alt.Y("Name", title = None, sort = "-x")

    ).transform_filter(selection).properties(height = 800, width = 600, title = "Gaming habits of your friend group")
    
    text = base.mark_text(align = "center", baseline = "top").encode(
        x = alt.value(300),
        y = alt.value(830),
        text = alt.Text("Text"),
        size = alt.value(20)
    )
    
    image = base.mark_image().encode(
        url = "ProfilePicture"
    ).add_selection(selection).add_selection(brush).transform_filter(selection)
    
    c1 = (base + image + text).configure_title(fontSize = 24)
    
    return c1

# %%
compare_chart(plotData)
# Out:
# alt.LayerChart(...)

# %%
def development_dashboard(dataframe):
    selection_options = alt.binding_select(options = dataframe["variable"].unique().tolist())
    selection = alt.selection_single(name = "Genre", fields = ["variable"], bind = selection_options, init = {"variable": "Playtime"})
    brush = alt.selection_interval(empty = "none")
    
    base = alt.Chart(dataframe).mark_bar().encode(
        x = alt.Y("value", title = [" ", " "]),
        y = alt.Y("Name", title = None, sort = "-x")

    ).transform_filter(selection).properties(height = 800, width = 600, title = "Gaming habits of your friend group")
    
    text = base.mark_text(align = "center", baseline = "top").encode(
        x = alt.value(300),
        y = alt.value(830),
        text = alt.Text("Text"),
        size = alt.value(20)
    )
    
    image = base.mark_image().encode(
        url = "ProfilePicture"
    ).add_selection(selection).add_selection(brush).transform_filter(selection)
    
    c1 = (base + image + text)
    
    c2 = alt.Chart(dataframe).mark_bar(baseline = "middle").encode(
        x = alt.Y("count()"),
        y = alt.X("GameList")
    ).properties(width = 1000, height = 1000).transform_filter(selection).transform_filter(brush)
    
    c3 = (c1 | c2)
    return c3

# %%
development_dashboard(plotData).save("filename.html")

# %% [markdown]
# ### Prototype
