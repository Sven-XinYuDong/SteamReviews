# %%
import SteamFunctions.APICall as APICall

# %%
APICall.compare_genres_preference(['76561198025087893','76561198036542086'])
# Out:
#                steamid                 genres
# 0    76561198025087893                 Action
# 1    76561198025087893                 Racing
# 2    76561198025087893                 Racing
# 3    76561198025087893                 Action
# 4    76561198025087893                 Action
# ..                 ...                    ...
# 112  76561198036542086                 Action
# 113  76561198036542086              Adventure
# 114  76561198036542086           Free to Play
# 115  76561198036542086  Massively Multiplayer
# 116  76561198036542086                    RPG
#
# [205 rows x 2 columns]

# %%
import SteamFunctions.SteamDataExtraction as extract

# %%
theId = extract.get_friend_id(76561198025087893)

# %%
data = extract.get_game_library(extract.get_friend_name(theId))
# Out:
# Could not load game library for LambDaDawg
# Could not load game library for Violence AK47
# Could not load game library for キスショット
# Could not load game library for hansonfok
# Could not load game library for BarbieBabyGirl
# Could not load game library for Sevato
# Could not load game library for Kino
# Could not load game library for Crispy
# Could not load game library for Rice Ball
# Could not load game library for SeaW0NG
# Could not load game library for PurinPuuuding
# Could not load game library for Anti-Fun
# Could not load game library for ImYGbro
# Could not load game library for TouchingButt
# Could not load game library for Kotaru
# Could not load game library for dougylolz
# Could not load game library for 3pointshot
# Could not load game library for Jessums
# Could not load game library for 蕾娜
# Could not load game library for 小咲
# Could not load game library for Gwoo
# Could not load game library for 魚乾大大
# Could not load game library for Larry Mullen
# ...

# %%
import SteamFunctions.SteamDataFrameConverter as convert
import SteamFunctions.SteamChartCreator as chart

# %%
data = convert.friendlist_to_dataframe(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 data = convert.friendlist_to_dataframe(data)
#
# File ~/Downloads/SteamSMART/SteamFunctions/SteamDataFrameConverter.py:13, in friendlist_to_dataframe(friendNameList)
#      11 gameLst = [] #Start appending library of games to list
#      12 for game in friendNameList[friend][2]:
# ---> 13     gameLst.append(game["name"])
#      14 lst.append(gameLst) #End appending library of games to list
#      16 totalNumGamesOwned = len(gameLst) #Append total number of games owned
#
# TypeError: string indices must be integers

# %%
alt.data_transformers.disable_max_rows()

chart.development_dashboard(convert.chart_dataframe(data))
# Out:
# alt.HConcatChart(...)

# %%
import altair as alt
