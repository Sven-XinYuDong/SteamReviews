# %% [markdown]
# # Function Test
# ## 1. Steam_Review_Extraction

# %%
import Steam_Review_Extraction as SRE
import Reviews_Pivot as RP

# Get 1000 entries for game Stardew Valley (appid = 413150)
df = SRE.get_n_reviews(413150,10) 
df = SRE.review_cleaning(df)

# %%
df.head()
# Out:
#   recommendationid                                             author  \
# 0        129903781  {'steamid': '76561199010091155', 'num_games_ow...
# 1        130240585  {'steamid': '76561198115723593', 'num_games_ow...
# 2        130118576  {'steamid': '76561198139024395', 'num_games_ow...
# 3        130725600  {'steamid': '76561198278309723', 'num_games_ow...
# 4        130543890  {'steamid': '76561198244683594', 'num_games_ow...
#
#   language                                             review  \
# 0  english  after dedicating     hours of my blood  sweat ...
# 1  english             this game goes hard if you re autistic
# 2  english                                    better than sex
# 3  english                                                ...
# 4  english                                     you can be gay
#
#    timestamp_created  timestamp_updated  voted_up  votes_up  votes_funny  \
# 0         1672624934         1672624934      True       274          184
# ...

# %% [markdown]
# ## 2. Implementation 1

# %% [markdown]
# ## 3. Implementation 2

# %%
df = RP.Review_Sentiments_Labeling(df) # Give Labeling columns

# %%
df.iloc[1:5,[-3,-2,-1]] # show the Labeling
# Out:
#    polarity  subjectivity sentiment
# 1 -0.297222      0.380556  Negative
# 2  0.500000      0.500000  Positive
# 3  0.000000      0.000000  Positive
# 4  0.416667      0.583333  Positive

# %%
import altair as alt # Simple Viz for counts 

alt.Chart(df).mark_bar().encode(
    alt.Y('sentiment'),
    
    alt.X('count()'))
# Out:
# alt.Chart(...)

# %%
RP.Reveiew_Cloud_Glimpse(df) # WordCloud Figure
